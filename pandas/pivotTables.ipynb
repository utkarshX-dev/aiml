# %% [markdown]
# # Pivot Tables: We use aggregation functions here

# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

# %%
df
# Out:
#          Date Product Region  Sales  Units    Rep
# 0  2023-01-01       A   East    359     34   John
# 1  2023-01-02       B   West    397     88   Mary
# 2  2023-01-03       C  North    470     56    Bob
# 3  2023-01-04       D  South    649     92  Alice
# 4  2023-01-05       A   East    678     88   John
# 5  2023-01-06       B   West    806     73   Mary
# 6  2023-01-07       C  North    592     44    Bob
# 7  2023-01-08       D  South    637     82  Alice
# 8  2023-01-09       A   East    763     82   John
# 9  2023-01-10       B   West    757     77   Mary
# 10 2023-01-11       C  North    792     23    Bob
# 11 2023-01-12       D  South    433     93  Alice
# 12 2023-01-13       A   East    845     16   John
# 13 2023-01-14       B   West    167     78   Mary
# 14 2023-01-15       C  North    406     43    Bob
# 15 2023-01-16       D  South    778     44  Alice
# 16 2023-01-17       A   East    948     66   John
# 17 2023-01-18       B   West    170     11   Mary
# 18 2023-01-19       C  North    329     71    Bob
# 19 2023-01-20       D  South    873     31  Alice

# %%
pd.pivot_table(df, values='Sales', index='Region', columns='Product')
# Out:
# Product      A      B      C      D
# Region
# East     718.6    NaN    NaN    NaN
# North      NaN    NaN  517.8    NaN
# South      NaN    NaN    NaN  674.0
# West       NaN  459.4    NaN    NaN

# %%
pd.pivot_table(df, values='Sales', index='Region', columns='Product', aggfunc= 'median')
# Out:
# Product      A      B      C      D
# Region
# East     763.0    NaN    NaN    NaN
# North      NaN    NaN  470.0    NaN
# South      NaN    NaN    NaN  649.0
# West       NaN  397.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     718.6    NaN    NaN    NaN  57.2   NaN   NaN   NaN
# North      NaN    NaN  517.8    NaN   NaN   NaN  47.4   NaN
# South      NaN    NaN    NaN  674.0   NaN   NaN   NaN  68.4
# West       NaN  459.4    NaN    NaN   NaN  65.4   NaN   NaN

# %%
# Cross Tabs: We use counting functions here

# %%
pd.crosstab(df['Region'], df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
